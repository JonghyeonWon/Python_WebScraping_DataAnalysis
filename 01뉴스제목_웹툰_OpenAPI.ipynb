# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# requests, bs4 import
import requests 
# BeautifulSoup 클래스 import
import bs4
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)
print(res.status_code, res.ok)

# 응답(response)이 OK 이면
if res.ok:
    # 응답 (response)에서 text 추출
    html = res.text
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, 'html.parser')  
    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    # print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews']")))
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews']")
    print(type(a_tags))
    # <a> 태그 리스트 순회하기    
    for a_tag in a_tags:
        title = a_tag.text.strip()  # <a>제목</a>에서 제목 부분을 가져옴
        link = a_tag['href']
        # print(title, link)

# 응답(response)이 Error 이면 status code 출력    
else:
    print(f'Error Code: {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200 True
# <class 'bs4.element.ResultSet'>

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

# section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section_name):  #print_news('생활/문화') 
    sid = section_dict.get(section_name, '102')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
    }

    # requests 의 get() 함수 호출하기 
    res = requests.get(url, headers=req_header)

    # 응답(response)이 OK 이면
    if res.ok:
        # 응답 (response)에서 text 추출
        html = res.text
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, 'html.parser')  
        # CSS 선택자
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews']")
        # <a> 태그 리스트 순회하기    
        for a_tag in a_tags:
            title = a_tag.text.strip()  # <a>제목</a>에서 제목 부분을 가져옴
            link = a_tag['href']
            print(title, link)

    # 응답(response)이 Error 이면 status code 출력    
    else:
        print(f'Error Code: {res.status_code}')

# %%
print_news('경제')
# Out:
# 경제 뉴스 https://news.naver.com/section/101
# 반도체·태양광발전…국내 생산 시 2036년까지 세액공제 https://n.news.naver.com/mnews/article/032/0003462933
#  https://n.news.naver.com/mnews/article/comment/032/0003462933
# 교촌, 2분기 영업익 78억…전년比 15.7% 감소 https://n.news.naver.com/mnews/article/031/0001048107
#  https://n.news.naver.com/mnews/article/comment/031/0001048107
# GS리테일, 2분기 영업익 27.5%↑…체질개선 효과 본격화 https://n.news.naver.com/mnews/article/014/0005558535
#  https://n.news.naver.com/mnews/article/comment/014/0005558535
# "아직은 썰렁"…홈플러스, 재개장 첫날 입고율 30% 그쳐[르포] https://n.news.naver.com/mnews/article/421/0009102533
#  https://n.news.naver.com/mnews/article/comment/421/0009102533
# ‘하닉 1주에 하한가’…프리마켓 상·하한가 한시 금지 https://n.news.naver.com/mnews/article/023/0003991838
#  https://n.news.naver.com/mnews/article/comment/023/0003991838
# 한전, 신임사장 공모 착수… 전직 관료·광주시장 등 하마평 https://n.news.naver.com/mnews/article/011/0004649203
#  https://n.news.naver.com/mnews/article/comment/011/0004649203
#  https://n.news.naver.com/mnews/article/comment/138/0002237055
# 엔비디아 HBM 축소 우려…SK하이닉스 4.8% 하락[핫종목](종합) https://n.news.naver.com/mnews/article/421/0009102945
#  https://n.news.naver.com/mnews/article/comment/421/0009102945
# 미국, 중국 폴리실리콘 수입 규제…국내 태양광 반사이익 기대 https://n.news.naver.com/mnews/article/001/0016239537
#  https://n.news.naver.com/mnews/article/comment/001/0016239537
# 김태호 "신동국 두달전 만났다"…한미약품 법카 제보와는 무관 [현장+] https://n.news.naver.com/mnews/article/293/0000088769
#  https://n.news.naver.com/mnews/article/comment/293/0000088769
# 태릉·과천 그린벨트 해제 총량 예외 절차 진행… ‘공급 속도전’ 나선 정부 https://n.news.naver.com/mnews/article/022/0004149222
#  https://n.news.naver.com/mnews/article/comment/022/0004149222
# SK하이닉스, 보통주 1주당 375원 배당…“주주환원안 3분기 중 확정” https://n.news.naver.com/mnews/article/082/0001393028
#  https://n.news.naver.com/mnews/article/comment/082/0001393028
# 한미, 잇단 지배구조 논란에 선 긋기…"전문경영인 체제 굳건" https://n.news.naver.com/mnews/article/123/0002388018
#  https://n.news.naver.com/mnews/article/comment/123/0002388018
# "재건축 주택 순증 효과 44%"…서울시, 대통령실에 규제 완화 건의 https://n.news.naver.com/mnews/article/629/0000522728
#  https://n.news.naver.com/mnews/article/comment/629/0000522728

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':''
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    pass
    # requests 의 get(url, headers) 함수 호출하기 
        
        # binary 응답 데이터 가져오기
        
        # url에서 파일명만 추출하기
        
        # binday data를 file에 write하기

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### .env 파일에서 환경변수 읽어오기
# * CLIENT_ID와 CLIENT_SECRET 환경변수 읽어오기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * [네이버개발자가이드](https://developers.naver.com/docs/utils/captcha/examples/)
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# ### 5-1. 블로그 검색하기
# * 네이버 개발자센터에서 제공하는 검색 API 사용하기

# %%
import requests
from pprint import pprint

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)

# json() 함수로 응답 결과 가져오기 [{},{},{}]
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %% [markdown]
# ### 5-2. 블로그 검색하기
# * 네이버 API HUB (NAVER Cloud)에서 제공하는 검색 API 사용하기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %%
import requests
from pprint import pprint

headers = {
    'X-NCP-APIGW-API-KEY-ID': CLIENT_ID,
    'X-NCP-APIGW-API-KEY': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}
domain_url = 'https://naverapihub.apigw.ntruss.com'
url = f'{domain_url}/search/v1/blog'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기 [{},{},{}]
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %%
# data/blog.json 파일 생성하기
import json

with open('data/blog.json','w', encoding='utf-8') as file:
    json.dump(items_data, file)
